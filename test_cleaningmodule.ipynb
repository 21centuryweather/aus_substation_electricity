# %% [markdown]
# # Testing my .py cleaning module
# - module is an updated version of Mat's import_substation.py file
# - this test will see if the module can load/work, extract ID correctly and metadata matching
# - module only cleans the new demand QLD and VIC data, and processes it with the metadata

# %%
import sys
sys.path.append("/home/565/pv3484/aus_substation_electricity")

# %cd /home/565/pv3484/aus_substation_electricity/data/raw_data/QLD_demand/Energex_QLD

# %ls
# Out:
# /g/data/ng72/pv3484/substation_data/raw_data/QLD_demand/Energex_QLD
# collated_deduplicated_energex_2004_mw_30min.csv*
# collated_deduplicated_energex_2005_mw_30min.csv*
# collated_deduplicated_energex_2006_mw_30min.csv*
# collated_deduplicated_energex_2007_mw_30min.csv*
# collated_deduplicated_energex_2008_mw_30min.csv*
# collated_deduplicated_energex_2009_mw_30min.csv*
# collated_deduplicated_energex_2010_mw_30min.csv*
# collated_deduplicated_energex_2011_mw_30min.csv*
# collated_deduplicated_energex_2012_mw_30min.csv*
# collated_deduplicated_energex_2013_mw_30min.csv*
# collated_deduplicated_energex_2014_mw_30min.csv*
# collated_deduplicated_energex_2015_mw_30min.csv*
# collated_deduplicated_energex_2016_mw_30min.csv*
# collated_deduplicated_energex_2017_mw_30min.csv*
# collated_deduplicated_energex_2018_mw_30min.csv*

# %%
from cleaning_demand2 import load_supplier_demand_and_metadata
from pathlib import Path
import pandas as pd

META = Path("/home/565/pv3484/aus_substation_electricity/data/DNSP_Zone_Substation_Characteristics.csv")
supplier_csv = Path("/home/565/pv3484/aus_substation_electricity/data/raw_data/QLD_demand/Energex_QLD/collated_deduplicated_energex_2012_mw_30min.csv")

metadata_df = pd.read_csv(META)

# 👉 Add this line here to inspect the columns
metadata_df.columns.tolist()

demand, meta = load_supplier_demand_and_metadata(supplier_csv, metadata_df)

#demand.head()
meta.head(10)
# Out:
#     Distribution Network Service Provider energy_asset Zone Substation Name  \
# 145                       AusNet Services       AS_BDL           Bairnsdale
# 149                       AusNet Services       AS_BRT               Bright
# 162                       AusNet Services       AS_HPK         Hampton Park
# 183                       AusNet Services       AS_SMR              Seymour
# 351                               Energex       EX_ABY             Amberley
# 352                               Energex       EX_ACR         Albany Creek
# 353                               Energex       EX_AGE             Ashgrove
# 354                               Energex       EX_AGT             Algester
# 355                               Energex       EX_AHD   Alexandra Headland
# 356                               Energex       EX_AHL          Arana Hills
#
#       ID  Zone Substation Area (km2)  Dwellings  Persons  Residential  \
# 145  BDL                        7602      19613    37659        0.009
# 149  BRT                         573       3606     4957        0.055
# 162  HPK                          53      29088    93224        0.614
# 183  SMR                        2744       9986    21141        0.036
# 351  ABY                          65        605     1675        0.129
# 352  ACR                          29       8057    22829        0.768
# 353  AGE                          11       8085    20603        0.671
# 354  AGT                          20       4217    11756        0.228
# 355  AHD                          30      20687    38921        0.556
# 356  AHL                          27      12541    32660        0.661
#
#      Commercial  Industrial  Primary Production  Education  Hospital/Medical  \
# 145       0.000       0.000               0.427      0.000             0.000
# 149       0.000       0.000               0.338      0.000             0.000
# 162       0.044       0.119               0.028      0.009             0.000
# 183       0.000       0.000               0.805      0.000             0.000
# 351       0.000       0.039               0.769      0.000             0.000
# 352       0.007       0.000               0.000      0.014             0.000
# 353       0.032       0.000               0.000      0.039             0.000
# 354       0.008       0.189               0.000      0.005             0.000
# 355       0.094       0.027               0.085      0.021             0.003
# 356       0.006       0.003               0.000      0.012             0.000
#
#      Transport  Parkland  Water  Other
# 145      0.000     0.519  0.033  0.011
# 149      0.000     0.592  0.000  0.015
# 162      0.002     0.106  0.000  0.079
# 183      0.001     0.146  0.000  0.012
# 351      0.000     0.007  0.000  0.055
# 352      0.000     0.209  0.000  0.002
# 353      0.000     0.258  0.000  0.000
# 354      0.000     0.118  0.000  0.452
# 355      0.000     0.107  0.106  0.000
# 356      0.003     0.315  0.000  0.000

# %%
meta["Distribution Network Service Provider"].unique()
# Out:
# array(['AusNet Services', 'Energex', 'Essential Energy', 'Jemena',
#        'Powercor', 'United Energy', 'Western Power'], dtype=object)

# %%
demand.columns.tolist()
# Out:
# ['ABY',
#  'ACR',
#  'AGE',
#  'AGT',
#  'AHD',
#  'AHL',
#  'ALY',
#  'AMR',
#  'ARG',
#  'ARL',
#  'AST',
#  'ATC',
#  'BBH',
#  'BBS',
#  'BDA',
#  'BDB',
#  'BDL',
#  'BDT',
#  'BGY',
#  'BHD',
#  'BIS',
#  'BKD',
#  'BLB',
#  'BLH',
#  'BLN',
#  'BMT',
#  'BNH',
#  'BPN',
#  'BRD',
#  'BRT',
#  'BTA',
#  'BTN',
#  'BVL',
#  'BWH',
#  'CBT',
#  'CBW',
#  'CCY',
#  'CFD',
#  'CHL',
#  'CLD',
#  'CLM',
#  'CMA',
#  'CMD',
#  'CMV',
#  'CMY',
#  'CNA',
#  'CNB',
#  'COR',
#  'CPB',
#  'CPC',
#  'CPD',
#  'CPK',
#  'CPL',
#  'CPR',
#  'CRB',
#  'CRM',
#  'CRY',
#  'CSE',
#  'CST',
#  'CVL',
#  'DBY',
#  'DRA',
#  'DRD',
#  'EMD',
#  'ENG',
#  'ESK',
#  'FDS',
#  'GAP',
#  'GBG',
#  'GBN',
#  'GGR',
#  'GLY',
#  'GTN',
#  'GVN',
#  'GYM',
#  'GYN',
#  'GYS',
#  'HDA',
#  'HDN',
#  'HIS',
#  'HMT',
#  'HPE',
#  'HPK',
#  'HTN',
#  'HWD',
#  'HWL',
#  'IBL',
#  'IDY',
#  'INA',
#  'IPL',
#  'IPS',
#  'JBB',
#  'JDL',
#  'KBN',
#  'KBR',
#  'KCY',
#  'KLG',
#  'KMR',
#  'KRA',
#  'KRN',
#  'KSN',
#  'KWA',
#  'KWH',
#  'LBH',
#  'LDR',
#  'LGL',
#  'LGV',
#  'LHM',
#  'LLY',
#  'LRE',
#  'LTA',
#  'LTN',
#  'LWD',
#  'MAI',
#  'MBG',
#  'MCN',
#  'MCW',
#  'MDR',
#  'MFD',
#  'MFN',
#  'MGL',
#  'MGP',
#  'MLB',
#  'MLS',
#  'MLT',
#  'MLY',
#  'MMC',
#  'MRE',
#  'MRK',
#  'MST',
#  'MTG',
#  'NBR',
#  'NDH',
#  'NGE',
#  'NGI',
#  'NIP',
#  'NMC',
#  'NMK',
#  'NRA',
#  'NRG',
#  'NSD',
#  'NSW',
#  'NVL',
#  'OXL',
#  'PBH',
#  'PGN',
#  'PKW',
#  'PPE',
#  'PRG',
#  'PWC',
#  'QPT',
#  'RBA',
#  'RBK',
#  'RBY',
#  'RCF',
#  'RCN',
#  'RIS',
#  'RLA',
#  'RLB',
#  'RPN',
#  'RST',
#  'RWD',
#  'SBH',
#  'SBK',
#  'SBY',
#  'SFD',
#  'SGT',
#  'SHW',
#  'SIS',
#  'SMF',
#  'SMR',
#  'SPC',
#  'SPD',
#  'SPE',
#  'SPF',
#  'SPO',
#  'SRD',
#  'STL',
#  'TBV',
#  'TCB',
#  'TGP',
#  'TGW',
#  'THL',
#  'TMH',
#  'TPT',
#  'TRG',
#  'TRP',
#  'TSN',
#  'TWG',
#  'TWT',
#  'UMG',
#  'VPK',
#  'VPT',
#  'VSL',
#  'WCL',
#  'WED',
#  'WFD',
#  'WHO',
#  'WMD',
#  'WMR',
#  'WNM',
#  'WRD',
#  'WRG',
#  'WSE',
#  'WSO',
#  'YDA',
#  'YTA',
#  'ZMR']

# %% [markdown]
# # Practice plotting
# - plotting Aus Day 2012 for the first 3 substations in brisbane

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Slice Australia Day 2012
aus_day = demand.loc["2012-01-26"]

# First 3 substations
substations = demand.columns[:3]

fig, axes = plt.subplots(3, 1, figsize=(12, 10), sharex=True)

for ax, sub in zip(axes, substations):
    ax.plot(aus_day.index, aus_day[sub])
    ax.set_title(f"Substation {sub} — Australia Day 2012")
    ax.set_ylabel("Demand (MW)")

    # Hourly ticks
    ax.xaxis.set_major_locator(mdates.HourLocator(interval=1))
    ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))

    # ⭐ Rotate x-axis labels
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right")

axes[-1].set_xlabel("Time of Day")

plt.tight_layout()
plt.close()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Slice Australia Day 2012
aus_day = demand.loc["2012-01-26"]

# First 3 substations
substations = demand.columns[:3]

# Lookup: ID → full name
name_lookup = meta.set_index("ID")["Zone Substation Name"].to_dict()

fig, axes = plt.subplots(3, 1, figsize=(12, 10), sharex=True)

for ax, sub in zip(axes, substations):
    ax.plot(aus_day.index, aus_day[sub])

    full_name = name_lookup.get(sub, sub)  # fallback to ID if missing

    ax.set_title(f"{full_name} ({sub}) — Australia Day 2012")
    ax.set_ylabel("Demand (MW)")

    # Hourly ticks
    ax.xaxis.set_major_locator(mdates.HourLocator(interval=1))
    ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))

    # Rotate labels
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right")

axes[-1].set_xlabel("Time of Day")

plt.tight_layout()
plt.show()
