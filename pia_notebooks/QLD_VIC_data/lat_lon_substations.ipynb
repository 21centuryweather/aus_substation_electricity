# %% [markdown]
# # Plotting VIC demand vs temperature
# - x axis = time (24hr period public holiday)
# - y axis = demand and temperature (hourly)

# %%
import pandas as pd

df = pd.read_parquet(
    "/g/data/ng72/pv3484/substation_data/cleaned_data/VIC/cleaned_obs/086038_ESSENDON_AIRPORT_cleaned.parquet"
)

df.columns.tolist()
# Out:
# ['hd',
#  'station_number',
#  'year',
#  'month',
#  'day',
#  'hour',
#  'minute',
#  'year_month_day_hour_minutes_in_yyyy.1',
#  'mm.1',
#  'dd.1',
#  'hh24.1',
#  'mi_format_in_local_standard_time',
#  'total_precipitation_in_last_5_minutes_in_mm_where_observations_count_>=_2',
#  'quality_total_precipitation_in_last_5_minutes',
#  'count_of_total_precipitation_observations_in_last_5_minutes',
#  'air_temperature_in_degrees_celsius',
#  'quality_of_air_temperature',
#  'highest_air_temperature_in_last_5_minutes_in_degrees_celsius_where_observations_count_>=_2',
#  'quality_of_highest_air_temperature_in_last_5_minutes',
#  'count_of_highest_air_temperature_observations_in_last_5_minutes',
#  'lowest_air_temperature_in_last_5_minutes_in_degrees_celsius_where_observations_count_>=_2',
#  'quality_of_lowest_air_temperature_in_last_5_minutes',
#  'count_of_lowest_air_temperature_observations_in_last_5_minutes',
#  'dew_point_temperature_in_degrees_celsius',
#  'quality_of_dew_point_temperature',
#  'average_wind_speed_in_last_5_minutes_in_km/h_where_observations_count_>=_2',
#  'quality_of_average_wind_speed_in_last_5_minutes',
#  'count_of_average_wind_speed_observations_in_last_5_minutes',
#  'lowest_wind_speed_in_last_5_minutes_in_km/h_where_observations_count_>=_2',
#  'quality_of_lowest_wind_speed_in_last_5_minutes',
#  'count_of_lowest_wind_speed_observations_in_last_5_minutes',
#  'highest_maximum_3_sec_wind_gust_in_last_5_minutes_in_km/h_where_observations_count_>=_2',
#  'quality_of_highest_maximum_3_sec_wind_gust_in_last_5_minutes',
#  'count_of_highest_maximum_3_sec_wind_gust_observations_in_last_5_minutes',
#  'average_direction_of_wind_in_last_5_minutes_in_degrees_true_where_observations_count_>=_2',
#  'quality_of_average_direction_of_wind_in_last_5_minutes',
#  'count_of_average_direction_of_wind_observations_in_last_5_minutes',
#  '#',
#  'datetime',
#  'record_type',
#  'station_id',
#  'district_code',
#  'name',
#  'opened',
#  'closed',
#  'lat',
#  'lon',
#  'elev',
#  'state',
#  'col10',
#  'col11',
#  'wmo',
#  'start_year',
#  'end_year',
#  'col15',
#  'col16',
#  'col17',
#  'col18',
#  'col19',
#  'col20',
#  'col21',
#  'record_identifier_st',
#  'rainfall_district_code',
#  'month_year_site_opened',
#  'month_year_site_closed',
#  'method_by_which_latitude_longitude_was_derived',
#  'height_of_station_above_mean_sea_level_in_metres',
#  'height_of_barometer_above_mean_sea_level_in_metres',
#  'wmo_index_number',
#  'first_year_of_data_supplied_in_data_file',
#  'last_year_of_data_supplied_in_data_file',
#  'percentage_complete_between_first_and_last_records',
#  'percentage_of_values_with_quality_flag_y',
#  'percentage_of_values_with_quality_flag_n',
#  'percentage_of_values_with_quality_flag_w',
#  'percentage_of_values_with_quality_flag_s',
#  'percentage_of_values_with_quality_flag_i',
#  'symbol_end_of_record_indicator']
