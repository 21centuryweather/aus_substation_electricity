# %%
#This gets us into the right directory from home, in order to run the import python script from Mat

#sys = system (module), gives information and control over python interpreter/terminal itself
import sys
sys.path.append("/home/565/pv3484/aus_substation_electricity_old")

#% is a magic command, special shortcut command that lets you control/interact with notebook environment (ie. gives control of terminal without writing full python code)
# %cd aus_substation_electricity_old/

# !pwd
# Out:
# /home/565/pv3484/aus_substation_electricity_old
# /home/565/pv3484/aus_substation_electricity_old

# %%
#This section imports the substations that Mat put together

# %run /home/565/pv3484/aus_substation_electricity_old/import_substation.py
# Out:
# processing nsw substations for ['ausgrid'] from None to None
# ausgrid
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/aus_substation_electricity_old/import_substation.py:407
#     405 for domain in domains:
#     406     suppliers, supplier, obs_fpath = get_domain_info(domain)
# --> 407     demand, info, obs = get_demand_data(suppliers,domain,sdate,edate)
#     409     print('\nsubstation info:\n', info)
#     410     print('\ncleaned demand data:\n', demand)
#
# File ~/aus_substation_electricity_old/import_substation.py:49, in get_demand_data(suppliers, domain, sdate, edate)
#      47 for supplier in suppliers:
#      48     print(supplier)
# ---> 49     demand,info = get_supplier_demand(supplier)
#      50     # clean data
#      51     demand = clean_data(demand,obs)
#
# File ~/aus_substation_electricity_old/import_substation.py:243, in get_supplier_demand(supplier, area_min, res_min, res_max, com_min, com_max, ind_min, ind_max, farm_max)
#     240 fnames = sorted(glob.glob(f'{datapath}/{supplier}/collated_standardized_{supplier}*.csv'))
#     242 # get half hourly substation data and info
# --> 243 demand = pd.concat([get_substation_data(fname) for fname in fnames], sort=False)
#     245 # print any demand column that is not in info index
#     246 print('following columns in demand are not in info index:')
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.08/lib/python3.11/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.08/lib/python3.11/site-packages/pandas/core/reshape/concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.08/lib/python3.11/site-packages/pandas/core/reshape/concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
#printing the column names in info

print("Column names in obserations:",info.columns)
# Out:
# Column names in obserations: Index(['energy_asset', 'Name', 'Area', 'Dwellings', 'Persons', 'Residential', 'Commercial', 'Industrial', 'Primary Production', 'Education',
#        'Hospital/Medical', 'Transport', 'Parkland', 'Water', 'Other'],
#       dtype='object')

# %%
# This will give you data on the columns for the "obs" variable
print("Column names in demand:",obs.columns)
# Out:
# Column names in demand: Index(['t2m', 't2m_30max', 't2m_30min', 't2m_bin'], dtype='object')

# %%
#Finding out what is inside the obs dataframe

obs.shape #rows,columns
# Out:
# (403248, 4)

# %%
# This will give you data on the columns for the "demand" variable

print("Column names in demand:",demand.columns)
# Out:
# Column names in demand: Index(['BLAKE', 'PUNCH', 'MEADO', 'MOSMA', 'RIVER', 'CA_CO', 'DU_HI', 'FI_DO', 'UMINA', 'CAMPS', 'HU_HI', 'MORTD', 'CHATS', 'KOGAR', 'PE_HI',
#        'LIDCO', 'BURWO', 'HORNS', 'EPPIN', 'DE_WH', 'HARBO', 'SEFTO', 'MARRI', 'GR_PA', 'ENFIE', 'ARNCL', 'REVES', 'CARDI', 'TO_RY', 'NARRA',
#        'BANKS', 'CONCO', 'CARIN', 'BA_HI', 'NE_CB', 'MAROU', 'BA_NO', 'ADAMS', 'JESMO', 'KIRRA', 'BE_HI', 'WO_WO', 'CHARM', 'CHARL', 'ST_PE',
#        'BROOK', 'NORAV', 'CRONU', 'BROAD', 'ROCKD', 'GO_HI', 'ERINA', 'LEIGH', 'PO_HI', 'GATES', 'PYMBL', 'MASCO', 'MILPE', 'MATRA', 'MA_WE',
#        'BOTAN', 'EDGEW', 'FLEMI', 'ZETLA', 'SWANS', 'AVOCA', 'JEWEL', 'AUBUR', 'GR_SQ', 'MARYL', 'ARGEN', 'MA_PA', 'TELAR', 'NE_BA', 'LISAR',
#        'BEROW', 'HO_BA', 'SOMER', 'MORIS', 'WE_GO', 'WYONG', 'RUTHE', 'ROTHB', 'MUSWE'],
#       dtype='object')

# %%
#I want to plot some of this now
import numpy as np
import matplotlib.pyplot as plt #matplotlib.pyplot used as plt.'plot' function is not part of matplotlib module (but is part of matplotlib.pyplot)

blake_demand = demand['BLAKE']
blake_subset = np.array(blake_demand)
blake_subset = blake_subset[0:100]
#plt.plot(blake_subset)

#giving the plot heading and titles
plt.title("Electricity Demand in Blake")
plt.xlabel("Time")
plt.ylabel("Demand")

#automatically adjust so title fits
plt.tight_layout()

# %%
#plotting some data in obs

import numpy as np
import matplotlib.pyplot as plt

obs_temp = obs['t2m']
obs_subset = np.array(obs_temp)
obs_temp_ = obs_subset[0:4]

# %%
#attempt to plot t2_30min with blake demand data

import numpy as np
import matplotlib.pyplot as plt 

blake_demand = demand['BLAKE']
blake_subset = np.array(blake_demand)
blake_subset = blake_subset[0:100]
#plt.plot(blake_subset)

# %%
pwd
# Out:
# '/home/565/pv3484/aus_substation_electricity-main'

# %%
demand.shape
# Out:
# (205655, 84)
