# %% [markdown]
# # Looking at the new demand data sets (QLD)

# %% [markdown]
# ## Energex

# %%
import pandas as pd

path = "/g/data/ng72/pv3484/substation_data/raw_data/QLD_demand/Energex_QLD/collated_deduplicated_energex_2010_mw_30min.csv"
df = pd.read_csv(path)

df.head()          # first 5 rows
#df.columns         # all column names
#df.columns[:10]    # first 10 column names
# Out:
#      StartDeliveryTime      EndDeliveryTime UtilityName  \
# 0  2010-01-01 00:00:00  2010-01-01 00:30:00     Energex
# 1  2010-01-01 00:30:00  2010-01-01 01:00:00     Energex
# 2  2010-01-01 01:00:00  2010-01-01 01:30:00     Energex
# 3  2010-01-01 01:30:00  2010-01-01 02:00:00     Energex
# 4  2010-01-01 02:00:00  2010-01-01 02:30:00     Energex
#
#    'ABY'|'Amberley'|ActivePower  'ACR'|'Albany Creek'|ActivePower  \
# 0                      0.738769                          11.37500
# 1                      0.695312                          10.78130
# 2                      0.717041                           9.67188
# 3                      0.673584                           8.60938
# 4                      0.630126                           7.82813
#
#    'AGE'|'Ashgrove'|ActivePower  'AGT'|'Algester'|ActivePower  \
# 0                       9.98438                       6.62720
# 1                       9.75000                       6.21435
# ...

# %%
import pandas as pd

path = "//g/data/ng72/pv3484/substation_data/raw_data/VIC_demand/Jemena_VIC/collated_deduplicated_jemena_2013_mw_30min.csv"
df = pd.read_csv(path)

df.head()          # first 5 rows
#df.columns         # all column names
#df.columns[:10]    # first 10 column names
# Out:
#      StartDeliveryTime      EndDeliveryTime UtilityName  \
# 0  2013-01-01 00:00:00  2013-01-01 00:30:00      Jemena
# 1  2013-01-01 00:30:00  2013-01-01 01:00:00      Jemena
# 2  2013-01-01 01:00:00  2013-01-01 01:30:00      Jemena
# 3  2013-01-01 01:30:00  2013-01-01 02:00:00      Jemena
# 4  2013-01-01 02:00:00  2013-01-01 02:30:00      Jemena
#
#    'AW'|'Airport West Zone Substation'|ActivePower  \
# 0                                             30.5
# 1                                             29.4
# 2                                             28.3
# 3                                             27.4
# 4                                             26.7
#
#    'BY'|'Braybrook Zone Substation'|ActivePower  \
# 0                                           9.7
# 1                                           9.5
# 2                                           9.4
# 3                                           9.1
# 4                                           8.7
#
# ...

# %%
import pandas as pd

path = "/g/data/ng72/pv3484/substation_data/DNSP_Zone_Substation_Characteristics.csv"
df = pd.read_csv(path)

df.tail(30)
# Out:
#      Distribution Network Service Provider energy_asset Zone Substation Name  \
# 1268                         Western Power       WP_MYR               Myaree
# 1269                         Western Power         WP_N             Nedlands
# 1270                         Western Power        WP_NB          North Beach
# 1271                         Western Power        WP_NF      North Fremantle
# 1272                         Western Power       WP_NGN             Narrogin
# 1273                         Western Power       WP_NOR              Northam
# 1274                         Western Power        WP_NP          North Perth
# 1275                         Western Power        WP_OC             O Connor
# 1276                         Western Power        WP_OP         Osborne Park
# 1277                         Western Power       WP_PBY              Padbury
# 1278                         Western Power       WP_PCY           Piccadilly
# ...
