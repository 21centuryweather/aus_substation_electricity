# %% [markdown]
# # Running the QLD cleaning module
# - cleans demand data from metropolitan Brisbane (QLD)
# - processes it with the metadata
# - saves cleaned data into /home/565/pv3484/aus_substation_electricity/data/cleaned_data/QLD

# %%
import sys
sys.path.append("/home/565/pv3484/aus_substation_electricity/cleaning_data")

# %%
from QLD_cleaning import process_DNSP_years

# %%
from QLD_cleaning import process_DNSP_years

process_DNSP_years(
    dnspsubfolder="Ergon_network_QLD",
    state_dir="/home/565/pv3484/aus_substation_electricity/data/raw_data/QLD_demand",
    metadata_path="/home/565/pv3484/aus_substation_electricity/data/DNSP_Zone_Substation_Characteristics.csv",
    output_root="/home/565/pv3484/aus_substation_electricity/data/cleaned_data/QLD",
    sigma=5,
    remove_constant=True,
    fill_small_gaps=True,
    max_gap=4
)

# %% [markdown]
# # Running the VIC cleaning module
# - cleans demand data from metropolitan Melb (VIC)
# - processes it with the metadata
# - saves cleaned data into /home/565/pv3484/aus_substation_electricity/data/cleaned_data/VIC

# %% [markdown]
# ## Testing module by cleaning just CitiPower VIC

# %%
import pandas as pd
df = pd.read_csv("/home/565/pv3484/aus_substation_electricity/data/raw_data/VIC_demand/CitiPower_VIC/collated_standardized_citipower_2011_mw_30min.csv")
df.head()

# %%
import sys
sys.path.append("/home/565/pv3484/aus_substation_electricity/cleaning_data/substation_demand")

# %%
#AusNet_VIC will only process cleaned data from 2008-2015, 2016 and 2017 are having issues

from VIC_cleaning import process_DNSP_years

process_DNSP_years(
    dnspsubfolder="UnitedEnergy_VIC",
    state_dir="/home/565/pv3484/aus_substation_electricity/data/raw_data/VIC_demand",
    metadata_path="/home/565/pv3484/aus_substation_electricity/data/DNSP_Zone_Substation_Characteristics.csv",
    output_root="/home/565/pv3484/aus_substation_electricity/data/cleaned_data/VIC",
    sigma=5,
    remove_constant=True,
    fill_small_gaps=True,
    max_gap=4
)

# %%
#Re cleaning UnitedEnergy_VIC to reproduce metadata and fix 2016-2017
from VIC_cleaning import process_DNSP_years

process_DNSP_years(
    dnspsubfolder="UnitedEnergy_VIC",
    state_dir="/home/565/pv3484/aus_substation_electricity/data/raw_data/VIC_demand",
    metadata_path="/home/565/pv3484/aus_substation_electricity/data/DNSP_Zone_Substation_Characteristics.csv",
    output_root="/home/565/pv3484/aus_substation_electricity/data/cleaned_data/VIC",
    sigma=5,
    remove_constant=True,
    fill_small_gaps=True,
    max_gap=4
)
# Out:
# --- Starting DNSP: UnitedEnergy_VIC ---
#   Matched 44 metadata rows for 'United Energy'
#
# Processing file: collated_deduplicated_unitedenergy_2003_mw_30min.csv
# ...
# Gap filling: 100%|██████████| 44/44 [00:00<00:00, 1232.47col/s]
#   Saved cleaned file: UnitedEnergy_VIC_2003_cleaned.csv
#
# Processing file: collated_deduplicated_unitedenergy_2004_mw_30min.csv
# ...
# Gap filling: 100%|██████████| 44/44 [00:00<00:00, 939.30col/s]
#   Saved cleaned file: UnitedEnergy_VIC_2004_cleaned.csv
#
# Processing file: collated_deduplicated_unitedenergy_2005_mw_30min.csv
# ...
# Gap filling: 100%|██████████| 44/44 [00:00<00:00, 633.79col/s]
#   Saved cleaned file: UnitedEnergy_VIC_2005_cleaned.csv
#
# Processing file: collated_deduplicated_unitedenergy_2006_mw_30min.csv
# ...
# Gap filling: 100%|██████████| 44/44 [00:00<00:00, 667.78col/s]
#   Saved cleaned file: UnitedEnergy_VIC_2006_cleaned.csv
#
# Processing file: collated_deduplicated_unitedenergy_2007_mw_30min.csv
# ...
