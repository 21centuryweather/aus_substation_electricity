# %% [markdown]
# # Looking at the 5 minute weather obs
# - want to see how the csv are organised
# - how to open the csv files
# - get the correct station IDs for the areas I want

# %% [markdown]
# ## Greater Brisbane

# %%
import zipfile
from pathlib import Path

zip_path = Path("/home/565/pv3484/aus_substation_electricity/data/raw_data/GREATER_BRISBANE_obs/039089-040861.zip")
extract_dir = zip_path.with_suffix('')  # same name, no .zip

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# %%
stations = pd.read_csv(
    extract_dir / "HD01D_StnDet_9999999910708904.txt",
    sep=",",
    header=None,
    engine="python",
    encoding="utf-8",
    skiprows=1
)

stations.head()

# %%
stations.columns = [
    "record_type", "site_id", "site_num", "site_name", "start_date",
    "lat", "lon", "location_method", "state", "elev", "bar_ht", "wmo_id",
    "start_year", "end_year", "percent_complete", "percent_quality",
    "has_rain", "has_temp", "unknown1", "has_wind", "unknown2", "end_marker"
]

# %%
stations.head(10)

# %% [markdown]
# ## Melbourne

# %%
import zipfile
import pandas as pd
from pathlib import Path

zip_path = Path("/home/565/pv3484/aus_substation_electricity/data/raw_data/GREATER_MELBOURNE_obs/085099_086371.zip")
extract_dir = zip_path.with_suffix('')  # same name, no .zip

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# %%
stations = pd.read_csv(
    extract_dir / "HD01D_StnDet_9999999910708904.txt",
    sep=",",
    header=None,
    engine="python",
    encoding="utf-8",
    skiprows=1
)

stations.head()
# Out:
#    0      1   2                                         3        4        5   \
# 0  st  85151  85  YARRAM AIRPORT                            10/2007
# 1  st  85279  85  BAIRNSDALE AIRPORT                        07/1942
# 2  st  85280  85  MORWELL (LATROBE VALLEY AIRPORT)          01/1984
# 3  st  85291  85  MOUNT BAW BAW                             09/1991
# 4  st  85296  85  MOUNT MOORNAPA                            12/1993
#
#         6         7                8    9   ...     12    13    14  15  16  \
# 0 -38.5647  146.7479  GPS              VIC  ...  95890  2010  2024  99  99
# 1 -37.8818  147.5669  GPS              VIC  ...  94912  2008  2024  99  99
# 2 -38.2094  146.4746  GPS              VIC  ...  94891  2005  2024  99  99
# 3 -37.8384  146.2747  GPS              VIC  ...  95901  2011  2024  99  99
# 4 -37.7481  147.1428  GPS              VIC  ...  95913  2010  2024  99  99
#
#     17  18   19   20 21
# 0    *   0    *    *  #
# 1    *   0    *    *  #
# ...
